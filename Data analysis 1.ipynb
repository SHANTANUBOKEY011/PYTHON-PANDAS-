# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Ecommerce_Purchases[1]")
df.T
# Out:
#                                                                0     \
# Address           16629 Pace Camp Apt. 448\nAlexisborough, NE 77...
# Lot                                                           46 in
# AM or PM                                                         PM
# Browser Info      Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# Company                                             Martinez-Herman
# Credit Card                                        6011929061123406
# CC Exp Date                                                   02/20
# CC Security Code                                                900
# CC Provider                                            JCB 16 digit
# Email                                             pdunlap@yahoo.com
# Job                          Scientist, product/process development
# IP Address                                          149.146.147.205
# Language                                                         el
# ...

# %%
df['Purchase Price'].max()
df['Purchase Price'].min()
# Out:
# 0.0

# %%
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
len(df[df["Language"] == "fr"])
# Out:
# 10000

# %%
df[df["Language"] == "fr"].count()
# Out:
# Address             10000
# Lot                 10000
# AM or PM            10000
# Browser Info        10000
# Company             10000
# Credit Card         10000
# CC Exp Date         10000
# CC Security Code    10000
# CC Provider         10000
# Email               10000
# Job                 10000
# IP Address          10000
# Language            10000
# Purchase Price      10000
# dtype: int64

# %%
len(df[ df['Job'].str.contains('Engineer',case = True)])               ### strinng contains the word "Engineer"
# Out:
# 453

# %%
df[df['IP Address'] == '132.207.160.22']['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
len(df[(df['CC Provider'] == 'Mastercard')  &  (df['Purchase Price'] > 50)])
# Out:
# 405

# %%
df[(df['CC Provider'] == 'Mastercard')  &  (df['Purchase Price'] > 50)].count()
# Out:
# Address             405
# Lot                 405
# AM or PM            405
# Browser Info        405
# Company             405
# Credit Card         405
# CC Exp Date         405
# CC Security Code    405
# CC Provider         405
# Email               405
# Job                 405
# IP Address          405
# Language            405
# Purchase Price      405
# dtype: int64

# %%
df[df["CC Exp Date"].str.contains('20')].count()
# Out:
# Address             988
# Lot                 988
# AM or PM            988
# Browser Info        988
# Company             988
# Credit Card         988
# CC Exp Date         988
# CC Security Code    988
# CC Provider         988
# Email               988
# Job                 988
# IP Address          988
# Language            988
# Purchase Price      988
# dtype: int64

# %%
# Out:
# leekathy@yahoo.com           2
# joshua41@hotmail.com         2
# christopher29@gmail.com      2
# ethomas@hotmail.com          2
# brownjohn@hotmail.com        2
#                             ..
# jamesbarnett@gomez.org       1
# hernandezrobert@frank.com    1
# lindseywilliams@pratt.com    1
# ann28@hotmail.com            1
# rachelford@vaughn.com        1
# Name: Email, Length: 9954, dtype: int64

# %%
(df['Email'][i].split("@")[-1])
# Out:
# 'yahoo.com'

# %%
usernames = []
domains = []

# Split elements at "@" using a for loop
for email in df['Email']:
    parts = email.split('@')
    usernames.append(parts[-1])
